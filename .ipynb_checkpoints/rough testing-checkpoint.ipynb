# %%
from collections import defaultdict
from glob import glob
from random import choice, sample


from tensorflow.keras.layers import Input, Conv2D, Lambda, Dense, Flatten,MaxPooling2D,Activation, Dropout, BatchNormalization,  GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Subtract,Multiply
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from skimage.io import imshow
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import cv2
import os
from tqdm import tqdm
from tensorflow.keras.applications.resnet50 import preprocess_input
from random import sample, choice

# %%
# File paths
train_file_path = "data/train/"
train_relationships_path = "../csv_files/train_relationships.csv"
#the validation set will be family members F09...
validation_set = "F09"

#get all the images
all_images = glob(train_file_path + "*/*/*.jpg")

#seperate the train and validation sets
train_images = [img for img in all_images if validation_set not in img]
val_images = [img for img in all_images if validation_set in img]

# %%
print(len(all_images))
# Out:
# 12379

# %%
#create a dictionary with key=family member and value=list of pictures of family member
def fam_mem_pics(all_images):
    #create dictionary
    fam_member_dict = {}
    #create list for member pictures
    fam_member_lst = []
    i = 0
    while i < len(all_images)-1:
        #get the family member as key
        split_path = all_images[i].split('/')
        key = split_path[2]+'/'+split_path[3]
        #check if picture is about the same fmaily member
        same_member = True

        while same_member:
            #check if same family member
            if key in all_images[i]:
                #append the image to the family member list
                fam_member_lst.append(all_images[i])
                
            else:
                #changed family member
                same_member = False
            
            #update the counter to not go out of bounds
            if (i+1) < len(all_images):  
                i += 1
            else:
                #break if out of bounds
                break
                
        #check if key is already in dictionary - just in case the images are out of order
        if key in fam_member_dict.keys():
            #combine list
            fam_member_dict[key] = fam_member_dict[key] + fam_member_lst
        else: 
            #create key=family member and value= list of family member's pictures
            fam_member_dict[key] = fam_member_lst
        
        fam_member_lst = []
        
    #return the member_dictionary 
    return fam_member_dict

# %%
#get a family member image dictionary
map_train_person_to_images = fam_mem_pics(train_images)
map_val_person_to_images = fam_mem_pics(val_images)

# %%
map_train_person_to_images
# Out:
# {'F0832/MID1': ['data/train/F0832/MID1/P08797_face2.jpg',
#   'data/train/F0832/MID1/P08791_face1.jpg',
#   'data/train/F0832/MID1/P08795_face1.jpg',
#   'data/train/F0832/MID1/P08793_face1.jpg',
#   'data/train/F0832/MID1/P08799_face2.jpg',
#   'data/train/F0832/MID1/P08794_face4.jpg',
#   'data/train/F0832/MID1/P08792_face1.jpg'],
#  'F0832/MID2': ['data/train/F0832/MID2/P08791_face2.jpg',
#   'data/train/F0832/MID2/P08793_face5.jpg',
#   'data/train/F0832/MID2/P08795_face2.jpg',
#   'data/train/F0832/MID2/P08798_face2.jpg',
#   'data/train/F0832/MID2/P08800_face1.jpg',
#   'data/train/F0832/MID2/P08794_face1.jpg',
#   'data/train/F0832/MID2/P08792_face3.jpg'],
#  'F0832/MID5': ['data/train/F0832/MID5/P08796_face3.jpg',
#   'data/train/F0832/MID5/P08793_face6.jpg',
#   'data/train/F0832/MID5/P08792_face4.jpg'],
#  'F0832/MID4': ['data/train/F0832/MID4/P08796_face2.jpg',
#   'data/train/F0832/MID4/P08798_face1.jpg',
#   'data/train/F0832/MID4/P08793_face3.jpg',
#  'F0009/MID7': ['data/train/F0009/MID7/P11737_face4.jpg',
#   'data/train/F0009/MID7/P11736_face1.jpg',
#   'data/train/F0009/MID7/P11742_face2.jpg',
#   'data/train/F0009/MID7/P11745_face2.jpg',
#   'data/train/F0009/MID7/P11743_face5.jpg',
#   'data/train/F0009/MID7/P11739_face1.jpg'],
#  'F0009/MID2': ['data/train/F0009/MID2/P10570_face6.jpg',
#   'data/train/F0009/MID2/P00089_face2.jpg',
#   'data/train/F0009/MID2/P11716_face1.jpg',
#   'data/train/F0009/MID2/P10569_face1.jpg',
#   'data/train/F0009/MID2/P11723_face3.jpg',
#   'data/train/F0009/MID2/P11741_face5.jpg',
#   'data/train/F0009/MID2/P10577_face1.jpg',
#   'data/train/F0009/MID2/P11724_face3.jpg',
#   'data/train/F0009/MID2/P11717_face1.jpg',
#   'data/train/F0009/MID2/P10571_face2.jpg',
#   'data/train/F0009/MID2/P11755_face1.jpg',
#   'data/train/F0009/MID2/P11744_face3.jpg',
#   'data/train/F0009/MID2/P11733_face3.jpg',
#   'data/train/F0009/MID2/P10588_face1.jpg',
#   'data/train/F0009/MID2/P11721_face1.jpg',
#   'data/train/F0009/MID2/P10572_face1.jpg',
#   'data/train/F0009/MID2/P11735_face2.jpg',
#   'data/train/F0009/MID2/P10575_face3.jpg',
#   'data/train/F0009/MID2/P11757_face5.jpg',
#   'data/train/F0009/MID2/P11720_face4.jpg',
#   'data/train/F0009/MID2/P11726_face2.jpg',
#   'data/train/F0009/MID2/P11715_face1.jpg',
#   'data/train/F0009/MID2/P11743_face1.jpg',
#   'data/train/F0009/MID2/P11718_face1.jpg'],
#  'F0009/MID5': ['data/train/F0009/MID5/P11725_face3.jpg',
#   'data/train/F0009/MID5/P00089_face5.jpg',
#   'data/train/F0009/MID5/P11753_face2.jpg',
#   'data/train/F0009/MID5/P11722_face3.jpg',
#   'data/train/F0009/MID5/P10574_face2.jpg',
#   'data/train/F0009/MID5/P11744_face2.jpg',
#   'data/train/F0009/MID5/P11721_face4.jpg',
#   'data/train/F0009/MID5/P11733_face5.jpg',
#   'data/train/F0009/MID5/P11738_face1.jpg',
#   'data/train/F0009/MID5/P11735_face3.jpg',
#   'data/train/F0009/MID5/P11720_face6.jpg',
#   'data/train/F0009/MID5/P11751_face1.jpg',
#   'data/train/F0009/MID5/P10573_face1.jpg'],
#  'F0009/MID4': ['data/train/F0009/MID4/P11723_face1.jpg',
#   'data/train/F0009/MID4/P11754_face2.jpg',
#   'data/train/F0009/MID4/P11737_face1.jpg',
#   'data/train/F0009/MID4/P00089_face4.jpg',
#   'data/train/F0009/MID4/P11724_face1.jpg',
#   'data/train/F0009/MID4/P11741_face1.jpg',
#   'data/train/F0009/MID4/P10571_face1.jpg',
#   'data/train/F0009/MID4/P11735_face4.jpg',
#   'data/train/F0009/MID4/P11733_face2.jpg',
#   'data/train/F0009/MID4/P11744_face1.jpg',
#   'data/train/F0009/MID4/P10574_face5.jpg',
#   'data/train/F0009/MID4/P11756_face2.jpg',
#   'data/train/F0803/MID1/P08491_face2.jpg',
#   'data/train/F0803/MID1/P08488_face1.jpg',
#   'data/train/F0803/MID1/P08501_face2.jpg',
#   'data/train/F0803/MID1/P08497_face3.jpg',
#   'data/train/F0803/MID1/P08492_face1.jpg',
#   'data/train/F0803/MID1/P08499_face4.jpg',
#   'data/train/F0803/MID1/P08504_face1.jpg',
#   'data/train/F0803/MID1/P08494_face2.jpg',
#   'data/train/F0803/MID1/P08493_face2.jpg',
#   'data/train/F0803/MID1/P08505_face4.jpg',
#   'data/train/F0803/MID1/P08503_face2.jpg',
#   'data/train/F0803/MID1/P08487_face4.jpg'],
#  'F0803/MID2': ['data/train/F0803/MID2/P08501_face3.jpg',
#   'data/train/F0803/MID2/P08497_face2.jpg',
#   'data/train/F0803/MID2/P08499_face3.jpg',
#   'data/train/F0803/MID2/P08502_face2.jpg',
#   'data/train/F0803/MID2/P08505_face3.jpg',
#   'data/train/F0803/MID2/P08487_face2.jpg',
#   'data/train/F0803/MID2/P08493_face3.jpg',
#   'data/train/F0803/MID2/P08498_face2.jpg'],
#  'F0803/MID4': ['data/train/F0803/MID4/P08501_face1.jpg',
#   'data/train/F0803/MID4/P08492_face2.jpg',
#   'data/train/F0803/MID4/P08499_face2.jpg',
#   'data/train/F0803/MID4/P08494_face1.jpg',
#   'data/train/F0803/MID4/P08495_face1.jpg'],
#  'F0803/MID3': ['data/train/F0803/MID3/P08490_face1.jpg',
#   'data/train/F0803/MID3/P08506_face1.jpg',
#   'data/train/F0803/MID3/P08496_face1.jpg',
#   'data/train/F0803/MID3/P08500_face1.jpg',
#   'data/train/F0803/MID3/P08501_face5.jpg',
#   'data/train/F0803/MID3/P08488_face2.jpg',
#   'data/train/F0803/MID3/P08497_face1.jpg',
#   'data/train/F0803/MID3/P08504_face2.jpg',
#   'data/train/F0803/MID3/P08502_face1.jpg',
#   'data/train/F0803/MID3/P08499_face1.jpg',
#   'data/train/F0803/MID3/P08493_face1.jpg',
#   'data/train/F0803/MID3/P08505_face1.jpg',
#   'data/train/F0803/MID3/P08487_face3.jpg',
#   'data/train/F0803/MID3/P08498_face1.jpg',
#   'data/train/F0803/MID3/P08503_face1.jpg'],
#  'F0669/MID1': ['data/train/F0669/MID1/P06989_face1.jpg',
#   'data/train/F0669/MID1/P06990_face2.jpg',
#   'data/train/F0669/MID1/P06997_face2.jpg',
#   'data/train/F0669/MID1/P06991_face1.jpg',
#   'data/train/F0669/MID1/P06988_face1.jpg',
#   'data/train/F0669/MID1/P06994_face2.jpg',
#   'data/train/F0669/MID1/P06992_face1.jpg',
#   'data/train/F0669/MID1/P06995_face1.jpg'],
#  'F0669/MID2': ['data/train/F0669/MID2/P06990_face1.jpg',
#   'data/train/F0669/MID2/P06988_face2.jpg',
#   'data/train/F0669/MID2/P06994_face1.jpg',
#   'data/train/F0669/MID2/P06992_face3.jpg'],
#  'F0669/MID4': ['data/train/F0669/MID4/P06993_face1.jpg'],
#  'F0669/MID3': ['data/train/F0669/MID3/P06997_face1.jpg',
#   'data/train/F0669/MID3/P06991_face2.jpg',
#   'data/train/F0669/MID3/P06995_face2.jpg',
#   'data/train/F0669/MID3/P06993_face2.jpg'],
#  'F0656/MID1': ['data/train/F0656/MID1/P06894_face2.jpg',
#   'data/train/F0656/MID1/P06887_face1.jpg',
#   'data/train/F0656/MID1/P06895_face1.jpg',
#   'data/train/F0656/MID1/P06889_face1.jpg',
#   'data/train/F0656/MID1/P06888_face1.jpg',
#   'data/train/F0656/MID1/P06891_face1.jpg'],
#  'F0656/MID2': ['data/train/F0656/MID2/P06894_face1.jpg',
#   'data/train/F0656/MID2/P06887_face2.jpg',
#   'data/train/F0656/MID2/P06895_face2.jpg',
#   'data/train/F0656/MID2/P06889_face2.jpg',
#   'data/train/F0656/MID2/P06890_face1.jpg',
#   'data/train/F0656/MID2/P06891_face2.jpg',
#   'data/train/F0656/MID2/P06888_face4.jpg'],
#  'F0656/MID5': ['data/train/F0656/MID5/P06887_face3.jpg',
#   'data/train/F0656/MID5/P06895_face3.jpg',
#   'data/train/F0656/MID5/P06889_face4.jpg',
#   'data/train/F0656/MID5/P06888_face5.jpg'],
#  'F0656/MID4': ['data/train/F0656/MID4/P06889_face3.jpg'],
#  'F0464/MID1': ['data/train/F0464/MID1/P04897_face2.jpg',
#   'data/train/F0464/MID1/P04891_face1.jpg',
#   'data/train/F0464/MID1/P04900_face2.jpg',
#   'data/train/F0464/MID1/P04898_face2.jpg',
#   'data/train/F0464/MID1/P04895_face1.jpg',
#   'data/train/F0464/MID1/P04893_face1.jpg',
#   'data/train/F0464/MID1/P04899_face1.jpg',
#   'data/train/F0464/MID1/P04894_face2.jpg',
#   'data/train/F0464/MID1/P04902_face1.jpg'],
#  'F0464/MID3': ['data/train/F0464/MID3/P04901_face2.jpg',
#   'data/train/F0464/MID3/P04897_face1.jpg',
#   'data/train/F0464/MID3/P04900_face1.jpg',
#   'data/train/F0464/MID3/P04898_face1.jpg',
#   'data/train/F0464/MID3/P04895_face2.jpg',
#   'data/train/F0464/MID3/P04893_face2.jpg',
#   'data/train/F0464/MID3/P04899_face3.jpg',
#   'data/train/F0464/MID3/P04894_face1.jpg',
#   'data/train/F0464/MID3/P04902_face2.jpg'],
#  'F0038/MID1': ['data/train/F0038/MID1/P00400_face2.jpg',
#   'data/train/F0038/MID1/P00397_face1.jpg',
#   'data/train/F0038/MID1/P00401_face1.jpg',
#   'data/train/F0038/MID1/P00396_face3.jpg',
#   'data/train/F0038/MID1/P00395_face2.jpg',
#   'data/train/F0038/MID1/P00398_face1.jpg',
#   'data/train/F0038/MID1/P00404_face1.jpg',
#   'data/train/F0038/MID1/P00393_face2.jpg',
#   'data/train/F0038/MID1/P00394_face2.jpg',
#   'data/train/F0038/MID1/P00399_face1.jpg',
#   'data/train/F0038/MID1/P00403_face1.jpg',
#   'data/train/F0038/MID1/P00392_face2.jpg'],
#  'F0038/MID2': ['data/train/F0038/MID2/P00396_face4.jpg',
#   'data/train/F0038/MID2/P00395_face1.jpg',
#   'data/train/F0038/MID2/P00402_face1.jpg',
#   'data/train/F0038/MID2/P00393_face1.jpg',
#   'data/train/F0038/MID2/P00394_face1.jpg',
#   'data/train/F0038/MID2/P00399_face2.jpg',
#   'data/train/F0038/MID2/P00392_face1.jpg'],
#  'F0038/MID4': ['data/train/F0038/MID4/P00401_face2.jpg',
#   'data/train/F0038/MID4/P00398_face2.jpg',
#   'data/train/F0038/MID4/P00402_face2.jpg',
#   'data/train/F0038/MID4/P00399_face3.jpg'],
#  'F0038/MID3': ['data/train/F0038/MID3/P00403_face2.jpg',
#   'data/train/F0038/MID3/P00394_face3.jpg'],
#  'F0651/MID1': ['data/train/F0651/MID1/P06850_face2.jpg',
#   'data/train/F0651/MID1/P06851_face1.jpg',
#   'data/train/F0651/MID1/P06848_face1.jpg',
#   'data/train/F0651/MID1/P06846_face1.jpg',
#   'data/train/F0651/MID1/P06852_face1.jpg',
#   'data/train/F0651/MID1/P06855_face2.jpg',
#   'data/train/F0651/MID1/P06853_face1.jpg',
#   'data/train/F0651/MID1/P06847_face1.jpg'],
#  'F0651/MID2': ['data/train/F0651/MID2/P06846_face2.jpg',
#   'data/train/F0651/MID2/P06855_face1.jpg',
#   'data/train/F0651/MID2/P06853_face2.jpg',
#   'data/train/F0651/MID2/P06847_face2.jpg'],
#  'F0651/MID3': ['data/train/F0651/MID3/P06850_face1.jpg',
#   'data/train/F0651/MID3/P06848_face2.jpg',
#   'data/train/F0651/MID3/P06852_face2.jpg'],
#  'F0497/MID1': ['data/train/F0497/MID1/P05258_face1.jpg',
#   'data/train/F0497/MID1/P05256_face1.jpg',
#   'data/train/F0497/MID1/P05257_face2.jpg'],
#  'F0497/MID2': ['data/train/F0497/MID2/P05260_face2.jpg',
#   'data/train/F0497/MID2/P05256_face2.jpg',
#   'data/train/F0497/MID2/P05257_face1.jpg'],
#  'F0497/MID3': ['data/train/F0497/MID3/P05260_face1.jpg'],
#  'F0408/MID1': ['data/train/F0408/MID1/P04297_face3.jpg',
#   'data/train/F0408/MID1/P04301_face1.jpg',
#   'data/train/F0408/MID1/P04294_face2.jpg',
#   'data/train/F0408/MID1/P04299_face2.jpg',
#   'data/train/F0408/MID1/P04298_face1.jpg',
#   'data/train/F0408/MID1/P04295_face1.jpg',
#   'data/train/F0408/MID1/P04303_face3.jpg'],
#  'F0408/MID2': ['data/train/F0408/MID2/P04299_face1.jpg',
#   'data/train/F0408/MID2/P04294_face1.jpg',
#   'data/train/F0408/MID2/P04302_face3.jpg',
#   'data/train/F0408/MID2/P04295_face2.jpg',
#   'data/train/F0408/MID2/P04303_face1.jpg',
#   'data/train/F0408/MID2/P04298_face2.jpg'],
#  'F0408/MID4': ['data/train/F0408/MID4/P04301_face2.jpg',
#   'data/train/F0408/MID4/P04302_face1.jpg'],
#  'F0850/MID1': ['data/train/F0850/MID1/P08980_face2.jpg',
#   'data/train/F0850/MID1/P08987_face1.jpg',
#   'data/train/F0850/MID1/P08981_face1.jpg',
#   'data/train/F0850/MID1/P08989_face1.jpg',
#   'data/train/F0850/MID1/P08984_face1.jpg',
#   'data/train/F0892/MID2/P09420_face1.jpg',
#   'data/train/F0892/MID2/P09418_face1.jpg'],
#  'F0892/MID4': ['data/train/F0892/MID4/P09417_face3.jpg',
#   'data/train/F0892/MID4/P09421_face7.jpg',
#   'data/train/F0892/MID4/P09414_face4.jpg',
#   'data/train/F0892/MID4/P09412_face2.jpg',
#   'data/train/F0892/MID4/P09419_face2.jpg',
#   'data/train/F0892/MID4/P09420_face4.jpg'],
#  'F0892/MID3': ['data/train/F0892/MID3/P09417_face4.jpg',
#   'data/train/F0892/MID3/P09421_face9.jpg',
#   'data/train/F0892/MID3/P09412_face1.jpg',
#   'data/train/F0892/MID3/P09414_face3.jpg',
#   'data/train/F0892/MID3/P09420_face3.jpg'],
#  'F0805/MID1': ['data/train/F0805/MID1/P08521_face5.jpg',
#   'data/train/F0805/MID1/P08527_face3.jpg',
#   'data/train/F0805/MID1/P08526_face1.jpg',
#   'data/train/F0805/MID1/P08520_face2.jpg',
#   'data/train/F0805/MID1/P08528_face2.jpg',
#   'data/train/F0805/MID1/P08525_face1.jpg',
#   'data/train/F0805/MID1/P08523_face1.jpg',
#   'data/train/F0805/MID1/P08529_face3.jpg'],
#  'F0805/MID7': ['data/train/F0805/MID7/P08527_face4.jpg',
#   'data/train/F0805/MID7/P08526_face2.jpg',
#   'data/train/F0805/MID7/P08528_face3.jpg',
#   'data/train/F0805/MID7/P08524_face2.jpg'],
#  'F0805/MID2': ['data/train/F0805/MID2/P08520_face1.jpg'],
#  'F0805/MID5': ['data/train/F0805/MID5/P08523_face2.jpg'],
#  'F0805/MID4': ['data/train/F0805/MID4/P08529_face1.jpg'],
#  'F0805/MID3': ['data/train/F0805/MID3/P08529_face4.jpg'],
#  'F0039/MID1': ['data/train/F0039/MID1/P00410_face2.jpg',
#   'data/train/F0039/MID1/P00408_face1.jpg',
#   'data/train/F0039/MID1/P00405_face1.jpg'],
#  'F0039/MID4': ['data/train/F0039/MID4/P00410_face1.jpg',
#   'data/train/F0039/MID4/P00408_face2.jpg'],
#  'F0465/MID1': ['data/train/F0465/MID1/P04906_face2.jpg',
#   'data/train/F0465/MID1/P04905_face1.jpg',
#   'data/train/F0465/MID1/P04908_face1.jpg',
#   'data/train/F0465/MID1/P04911_face2.jpg',
#   'data/train/F0465/MID1/P04910_face1.jpg',
#   'data/train/F0465/MID1/P04909_face3.jpg'],
#  'F0465/MID2': ['data/train/F0465/MID2/P04906_face1.jpg',
#   'data/train/F0465/MID2/P04908_face2.jpg',
#   'data/train/F0465/MID2/P04911_face1.jpg',
#   'data/train/F0465/MID2/P04905_face2.jpg',
#   'data/train/F0465/MID2/P04909_face4.jpg',
#   'data/train/F0465/MID2/P04910_face2.jpg'],
#  'F0233/MID6': ['data/train/F0233/MID6/P02472_face1.jpg'],
#  'F0233/MID1': ['data/train/F0233/MID1/P02473_face1.jpg',
#   'data/train/F0233/MID1/P02476_face23.jpg',
#   'data/train/F0233/MID1/P02470_face1.jpg',
#   'data/train/F0233/MID1/P02469_face1.jpg',
#   'data/train/F0233/MID1/P02468_face3.jpg',
#   'data/train/F0233/MID1/P02471_face2.jpg',
#   'data/train/F0233/MID1/P02477_face2.jpg'],
#  'F0233/MID5': ['data/train/F0233/MID5/P02472_face2.jpg'],
#  'F0233/MID3': ['data/train/F0233/MID3/P02468_face4.jpg'],
#  'F0491/MID1': ['data/train/F0491/MID1/P05175_face1.jpg',
#   'data/train/F0491/MID1/P05176_face2.jpg',
#   'data/train/F0491/MID1/P05169_face1.jpg',
#   'data/train/F0491/MID1/P05170_face1.jpg',
#   'data/train/F0491/MID1/P05171_face1.jpg'],
#  'F0491/MID2': ['data/train/F0491/MID2/P05178_face1.jpg',
#   'data/train/F0491/MID2/P05176_face1.jpg',
#   'data/train/F0491/MID2/P05170_face2.jpg',
#   'data/train/F0491/MID2/P05169_face2.jpg',
#   'data/train/F0491/MID2/P05171_face2.jpg'],
#  'F0491/MID3': ['data/train/F0491/MID3/P05174_face1.jpg',
#   'data/train/F0491/MID3/P05175_face2.jpg',
#   'data/train/F0491/MID3/P05173_face1.jpg'],
#  'F0498/MID6': ['data/train/F0498/MID6/P12101_face2.jpg'],
#  'F0498/MID1': ['data/train/F0498/MID1/P05261_face1.jpg',
#   'data/train/F0498/MID1/P12096_face1.jpg',
#   'data/train/F0498/MID1/P05266_face2.jpg',
#   'data/train/F0498/MID1/P12101_face3.jpg',
#   'data/train/F0498/MID1/P12097_face1.jpg',
#   'data/train/F0498/MID1/P05265_face1.jpg',
#   'data/train/F0498/MID1/P05268_face2.jpg',
#   'data/train/F0498/MID1/P05263_face1.jpg',
#   'data/train/F0498/MID1/P05269_face2.jpg',
#   'data/train/F0498/MID1/P05264_face2.jpg',
#   'data/train/F0498/MID1/P05270_face2.jpg',
#   'data/train/F0498/MID1/P12098_face1.jpg',
#   'data/train/F0498/MID1/P05262_face1.jpg',
#   'data/train/F0498/MID1/P12095_face1.jpg'],
#  'F0498/MID4': ['data/train/F0498/MID4/P12095_face2.jpg'],
#  'F0661/MID1': ['data/train/F0661/MID1/P06928_face2.jpg',
#   'data/train/F0661/MID1/P06923_face2.jpg',
#   'data/train/F0661/MID1/P06924_face2.jpg',
#   'data/train/F0661/MID1/P06929_face1.jpg',
#   'data/train/F0661/MID1/P06922_face1.jpg',
#   'data/train/F0661/MID1/P06917_face1.jpg',
#   'data/train/F0661/MID1/P06927_face2.jpg',
#   'data/train/F0661/MID1/P06921_face1.jpg',
#   'data/train/F0661/MID1/P06926_face1.jpg',
#   'data/train/F0661/MID1/P06920_face1.jpg',
#   'data/train/F0661/MID1/P06915_face2.jpg',
#   'data/train/F0661/MID1/P06918_face1.jpg'],
#  'F0661/MID2': ['data/train/F0661/MID2/P06923_face3.jpg',
#   'data/train/F0661/MID2/P06929_face3.jpg',
#   'data/train/F0661/MID2/P06917_face2.jpg',
#   'data/train/F0661/MID2/P06922_face3.jpg',
#   'data/train/F0661/MID2/P06927_face1.jpg',
#   'data/train/F0661/MID2/P06921_face2.jpg',
#   'data/train/F0661/MID2/P06926_face2.jpg',
#   'data/train/F0661/MID2/P06915_face1.jpg',
#  'F0659/MID2': ['data/train/F0659/MID2/P06906_face1.jpg',
#   'data/train/F0659/MID2/P06907_face1.jpg'],
#  'F0030/MID1': ['data/train/F0030/MID1/P00310_face4.jpg',
#   'data/train/F0030/MID1/P00302_face2.jpg',
#   'data/train/F0030/MID1/P00300_face4.jpg'],
#  'F0030/MID2': ['data/train/F0030/MID2/P00303_face1.jpg',
#   'data/train/F0030/MID2/P00304_face1.jpg',
#   'data/train/F0030/MID2/P00307_face2.jpg',
#   'data/train/F0030/MID2/P00301_face1.jpg',
#   'data/train/F0030/MID2/P00306_face2.jpg',
#   'data/train/F0030/MID2/P00300_face1.jpg'],
#  'F0030/MID4': ['data/train/F0030/MID4/P00309_face1.jpg'],
#  'F0030/MID3': ['data/train/F0030/MID3/P00305_face2.jpg',
#   'data/train/F0030/MID3/P00303_face2.jpg',
#   'data/train/F0030/MID3/P00304_face2.jpg',
#   'data/train/F0030/MID3/P00302_face1.jpg',
#   'data/train/F0030/MID3/P00307_face1.jpg',
#   'data/train/F0030/MID3/P00301_face2.jpg',
#   'data/train/F0030/MID3/P00306_face1.jpg'],
#  'F0202/MID1': ['data/train/F0202/MID1/P02174_face1.jpg',
#   'data/train/F0202/MID1/P02175_face1.jpg',
#   'data/train/F0202/MID1/P02173_face2.jpg',
#   'data/train/F0202/MID1/P02182_face1.jpg',
#   'data/train/F0202/MID1/P02176_face1.jpg',
#   'data/train/F0202/MID1/P02177_face2.jpg',
#   'data/train/F0202/MID1/P02180_face3.jpg'],
#  'F0202/MID2': ['data/train/F0202/MID2/P02176_face2.jpg'],
#  'F0202/MID5': ['data/train/F0202/MID5/P02178_face1.jpg',
#   'data/train/F0202/MID5/P02176_face3.jpg',
#   'data/train/F0202/MID5/P02177_face1.jpg',
#   'data/train/F0202/MID5/P02180_face2.jpg'],
#  'F0202/MID3': ['data/train/F0202/MID3/P02174_face2.jpg',
#   'data/train/F0202/MID3/P02178_face2.jpg',
#   'data/train/F0202/MID3/P02173_face1.jpg',
#   'data/train/F0202/MID3/P02176_face4.jpg',
#   'data/train/F0202/MID3/P02181_face1.jpg',
#   'data/train/F0202/MID3/P02177_face3.jpg',
#   'data/train/F0202/MID3/P02180_face1.jpg'],
#  'F0064/MID6': ['data/train/F0064/MID6/P10484_face2.jpg',
#   'data/train/F0064/MID6/P00652_face1.jpg',
#   'data/train/F0064/MID6/P00646_face2.jpg',
#   'data/train/F0064/MID6/P10481_face2.jpg',
#   'data/train/F0064/MID6/P00644_face2.jpg'],
#  'F0064/MID1': ['data/train/F0064/MID1/P00641_face2.jpg',
#   'data/train/F0064/MID1/P00655_face3.jpg',
#   'data/train/F0064/MID1/P00647_face1.jpg',
#   'data/train/F0064/MID1/P00653_face3.jpg',
#   'data/train/F0064/MID1/P00654_face3.jpg',
#   'data/train/F0064/MID1/P10482_face4.jpg',
#   'data/train/F0064/MID1/P00646_face3.jpg',
#   'data/train/F0064/MID1/P10484_face1.jpg',
#   'data/train/F0064/MID1/P00640_face5.jpg',
#   'data/train/F0064/MID1/P00652_face2.jpg',
#  'F0893/MID1': ['data/train/F0893/MID1/P09431_face2.jpg',
#   'data/train/F0893/MID1/P09428_face1.jpg',
#   'data/train/F0893/MID1/P09423_face1.jpg',
#   'data/train/F0893/MID1/P09429_face2.jpg',
#   'data/train/F0893/MID1/P09424_face1.jpg',
#   'data/train/F0893/MID1/P09430_face1.jpg',
#   'data/train/F0893/MID1/P09422_face2.jpg',
#   'data/train/F0893/MID1/P09427_face2.jpg',
#   'data/train/F0893/MID1/P09426_face2.jpg'],
#  'F0893/MID2': ['data/train/F0893/MID2/P09423_face5.jpg',
#   'data/train/F0893/MID2/P09424_face3.jpg',
#   'data/train/F0893/MID2/P09429_face1.jpg',
#   'data/train/F0893/MID2/P09430_face2.jpg'],
#  'F0893/MID4': ['data/train/F0893/MID4/P09423_face4.jpg',
#   'data/train/F0893/MID4/P09425_face2.jpg',
#   'data/train/F0893/MID4/P09422_face4.jpg'],
#  'F0893/MID3': ['data/train/F0893/MID3/P09423_face2.jpg',
#   'data/train/F0893/MID3/P09424_face2.jpg',
#   'data/train/F0893/MID3/P09422_face3.jpg',
#   'data/train/F0893/MID3/P09427_face1.jpg',
#   'data/train/F0893/MID3/P09426_face1.jpg'],
#  'F0063/MID1': ['data/train/F0063/MID1/P00629_face1.jpg',
#   'data/train/F0063/MID1/P00637_face2.jpg',
#   'data/train/F0063/MID1/P00631_face1.jpg',
#   'data/train/F0063/MID1/P00635_face2.jpg'],
#  'F0063/MID3': ['data/train/F0063/MID3/P00631_face2.jpg',
#   'data/train/F0063/MID3/P00634_face1.jpg',
#   'data/train/F0063/MID3/P00632_face1.jpg',
#   'data/train/F0063/MID3/P00633_face2.jpg'],
#  'F0635/MID1': ['data/train/F0635/MID1/P06666_face3.jpg',
#   'data/train/F0635/MID1/P06669_face2.jpg',
#   'data/train/F0635/MID1/P06670_face1.jpg',
#   'data/train/F0635/MID1/P06664_face2.jpg',
#   'data/train/F0635/MID1/P06668_face2.jpg',
#   'data/train/F0635/MID1/P06671_face2.jpg',
#   'data/train/F0635/MID1/P06665_face3.jpg'],
#  'F0635/MID5': ['data/train/F0635/MID5/P06666_face5.jpg',
#   'data/train/F0635/MID5/P06669_face1.jpg',
#   'data/train/F0635/MID5/P06670_face3.jpg',
#   'data/train/F0635/MID5/P06668_face1.jpg',
#   'data/train/F0635/MID5/P06665_face4.jpg'],
#  'F0635/MID4': ['data/train/F0635/MID4/P06672_face2.jpg',
#   'data/train/F0635/MID4/P06670_face2.jpg',
#   'data/train/F0635/MID4/P06668_face4.jpg',
#   'data/train/F0635/MID4/P06665_face5.jpg'],
#  'F0635/MID3': ['data/train/F0635/MID3/P06671_face1.jpg',
#   'data/train/F0635/MID3/P06665_face1.jpg',
#   'data/train/F0635/MID3/P06668_face3.jpg'],
#  'F0097/MID2': ['data/train/F0097/MID2/P00999_face2.jpg'],
#  'F0097/MID4': ['data/train/F0097/MID4/P01004_face2.jpg',
#   'data/train/F0097/MID4/P01003_face2.jpg',
#   'data/train/F0097/MID4/P01001_face2.jpg'],
#  'F0097/MID3': ['data/train/F0097/MID3/P01000_face2.jpg',
#   'data/train/F0097/MID3/P01007_face2.jpg'],
#  'F0438/MID6': ['data/train/F0438/MID6/P04631_face2.jpg',
#   'data/train/F0438/MID6/P04637_face4.jpg',
#   'data/train/F0438/MID6/P04630_face3.jpg',
#   'data/train/F0438/MID6/P04629_face2.jpg'],
#  'F0438/MID1': ['data/train/F0438/MID1/P04638_face1.jpg',
#   'data/train/F0438/MID1/P04621_face1.jpg',
#   'data/train/F0438/MID1/P04627_face3.jpg',
#   'data/train/F0438/MID1/P04633_face2.jpg',
#   'data/train/F0438/MID1/P04634_face2.jpg',
#   'data/train/F0438/MID1/P04620_face2.jpg',
#   'data/train/F0438/MID1/P04632_face1.jpg',
#   'data/train/F0438/MID1/P04623_face2.jpg',
#   'data/train/F0438/MID1/P04637_face1.jpg',
#   'data/train/F0438/MID1/P04625_face2.jpg',
#   'data/train/F0438/MID1/P04628_face2.jpg',
#   'data/train/F0438/MID1/P04629_face4.jpg',
#   'data/train/F0438/MID1/P04622_face1.jpg',
#   'data/train/F0438/MID1/P04630_face1.jpg'],
#  'F0438/MID7': ['data/train/F0438/MID7/P04625_face1.jpg',
#   'data/train/F0438/MID7/P04629_face7.jpg',
#   'data/train/F0438/MID7/P04630_face2.jpg'],
#  'F0438/MID2': ['data/train/F0438/MID2/P04635_face1.jpg',
#   'data/train/F0438/MID2/P04614_face1.jpg',
#   'data/train/F0438/MID2/P04619_face2.jpg',
#   'data/train/F0438/MID2/P04612_face2.jpg',
#   'data/train/F0438/MID2/P04620_face1.jpg',
#   'data/train/F0438/MID2/P04615_face1.jpg',
#   'data/train/F0438/MID2/P04618_face2.jpg',
#   'data/train/F0438/MID2/P04613_face2.jpg',
#   'data/train/F0438/MID2/P04637_face2.jpg',
#   'data/train/F0438/MID2/P04623_face1.jpg',
#   'data/train/F0438/MID2/P04631_face1.jpg',
#   'data/train/F0438/MID2/P04630_face4.jpg',
#   'data/train/F0438/MID2/P04629_face5.jpg'],
#  'F0438/MID5': ['data/train/F0438/MID5/P04634_face1.jpg',
#   'data/train/F0438/MID5/P04632_face2.jpg',
#   'data/train/F0438/MID5/P04628_face1.jpg',
#   'data/train/F0438/MID5/P04609_face1.jpg',
#   'data/train/F0438/MID5/P04622_face3.jpg',
#   'data/train/F0438/MID5/P04611_face2.jpg'],
#  'F0438/MID3': ['data/train/F0438/MID3/P04627_face2.jpg',
#   'data/train/F0438/MID3/P04612_face1.jpg',
#   'data/train/F0438/MID3/P04620_face4.jpg',
#   'data/train/F0438/MID3/P04632_face3.jpg',
#   'data/train/F0438/MID3/P04637_face3.jpg',
#   'data/train/F0438/MID3/P04616_face2.jpg',
#   'data/train/F0438/MID3/P04623_face3.jpg',
#   'data/train/F0438/MID3/P04610_face2.jpg',
#   'data/train/F0438/MID3/P04625_face3.jpg',
# ...
#   'data/train/F0664/MID4/P12395_face.jpg',
#   'data/train/F0664/MID4/P12401_face.jpg',
#   'data/train/F0664/MID4/P06945_face.jpg',
#   'data/train/F0664/MID4/P06943_face.jpg',
#   'data/train/F0664/MID4/P06942_face.jpg',
#   'data/train/F0664/MID4/P12414_face.jpg'],
#  'F0664/MID3': ['data/train/F0664/MID3/P12395_face.jpg',
#   'data/train/F0664/MID3/P06940_face.jpg',
#   'data/train/F0664/MID3/P12414_face.jpg'],
#  'F0456/MID1': ['data/train/F0456/MID1/P04817_face2.jpg',
#   'data/train/F0456/MID1/P04816_face2.jpg',
#   'data/train/F0456/MID1/P04813_face1.jpg',
#   'data/train/F0456/MID1/P04818_face1.jpg',
#   'data/train/F0456/MID1/P04820_face1.jpg',
#   'data/train/F0456/MID1/P04812_face2.jpg',
#   'data/train/F0456/MID1/P04819_face1.jpg',
#   'data/train/F0456/MID1/P04814_face1.jpg'],
#  'F0456/MID2': ['data/train/F0456/MID2/P04816_face1.jpg',
#   'data/train/F0456/MID2/P04813_face2.jpg',
#   'data/train/F0456/MID2/P04818_face3.jpg',
#   'data/train/F0456/MID2/P04815_face1.jpg',
#   'data/train/F0456/MID2/P04812_face1.jpg',
#   'data/train/F0456/MID2/P04819_face2.jpg'],
#  'F0456/MID4': ['data/train/F0456/MID4/P04816_face3.jpg',
#   'data/train/F0456/MID4/P04815_face2.jpg'],
#  'F0456/MID3': ['data/train/F0456/MID3/P04820_face2.jpg',
#   'data/train/F0456/MID3/P04818_face2.jpg',
#   'data/train/F0456/MID3/P04812_face3.jpg',
#   'data/train/F0456/MID3/P04814_face2.jpg'],
#  'F0690/MID1': ['data/train/F0690/MID1/P07201_face2.jpg',
#   'data/train/F0690/MID1/P07200_face2.jpg',
#   'data/train/F0690/MID1/P07198_face7.jpg',
#   'data/train/F0690/MID1/P07203_face1.jpg',
#   'data/train/F0690/MID1/P07205_face1.jpg',
#   'data/train/F0690/MID1/P07202_face1.jpg'],
#  'F0690/MID9': ['data/train/F0690/MID9/P07198_face8.jpg'],
#  'F0690/MID10': ['data/train/F0690/MID10/P07198_face5.jpg'],
#  'F0690/MID2': ['data/train/F0690/MID2/P07200_face1.jpg',
#   'data/train/F0690/MID2/P07198_face16.jpg'],
#  'F0690/MID4': ['data/train/F0690/MID4/P07203_face2.jpg',
#   'data/train/F0690/MID4/P07198_face13.jpg'],
#  'F0690/MID3': ['data/train/F0690/MID3/P07198_face3.jpg',
#   'data/train/F0690/MID3/P07205_face2.jpg',
#   'data/train/F0690/MID3/P07202_face2.jpg'],
#  'F0209/MID6': ['data/train/F0209/MID6/P02237_face3.jpg'],
#  'F0209/MID1': ['data/train/F0209/MID1/P02237_face2.jpg',
#   'data/train/F0209/MID1/P02236_face1.jpg',
#   'data/train/F0209/MID1/P02233_face1.jpg',
#   'data/train/F0209/MID1/P02235_face1.jpg',
#   'data/train/F0209/MID1/P02234_face1.jpg'],
#  'F0209/MID2': ['data/train/F0209/MID2/P02231_face7.jpg',
#   'data/train/F0209/MID2/P02237_face1.jpg',
#   'data/train/F0209/MID2/P02235_face4.jpg',
#   'data/train/F0209/MID2/P02233_face3.jpg'],
#  'F0209/MID4': ['data/train/F0209/MID4/P02235_face3.jpg'],
#  'F0209/MID3': ['data/train/F0209/MID3/P02231_face9.jpg'],
#  'F0838/MID1': ['data/train/F0838/MID1/P08859_face1.jpg',
#   'data/train/F0838/MID1/P08854_face1.jpg',
#   'data/train/F0838/MID1/P08853_face1.jpg',
#   'data/train/F0838/MID1/P08858_face2.jpg',
#   'data/train/F0838/MID1/P08856_face2.jpg',
#   'data/train/F0838/MID1/P08851_face2.jpg',
#   'data/train/F0838/MID1/P08857_face2.jpg'],
#  'F0236/MID1': ['data/train/F0236/MID1/P02497_face3.jpg',
#   'data/train/F0236/MID1/P02496_face3.jpg',
#   'data/train/F0236/MID1/P02500_face4.jpg',
#   'data/train/F0236/MID1/P02499_face6.jpg',
#   'data/train/F0236/MID1/P02502_face6.jpg'],
#  'F0236/MID2': ['data/train/F0236/MID2/P02496_face1.jpg',
#   'data/train/F0236/MID2/P02503_face2.jpg',
#   'data/train/F0236/MID2/P02505_face1.jpg',
#   'data/train/F0236/MID2/P02499_face3.jpg',
#   'data/train/F0236/MID2/P02504_face2.jpg'],
#  'F0236/MID4': ['data/train/F0236/MID4/P02501_face2.jpg',
#   'data/train/F0236/MID4/P02500_face2.jpg',
#   'data/train/F0236/MID4/P02498_face1.jpg',
#   'data/train/F0236/MID4/P02503_face1.jpg',
#   'data/train/F0236/MID4/P02495_face1.jpg',
#   'data/train/F0236/MID4/P02505_face3.jpg',
#   'data/train/F0236/MID4/P02493_face1.jpg',
#   'data/train/F0236/MID4/P02502_face1.jpg',
#   'data/train/F0236/MID4/P02504_face1.jpg',
#   'data/train/F0236/MID4/P02499_face5.jpg'],
#  'F0236/MID3': ['data/train/F0236/MID3/P02496_face4.jpg',
#   'data/train/F0236/MID3/P02498_face2.jpg'],
#  'F0460/MID6': ['data/train/F0460/MID6/P04869_face2.jpg',
#   'data/train/F0460/MID6/P04864_face2.jpg',
#   'data/train/F0460/MID6/P04862_face2.jpg'],
#  'F0460/MID1': ['data/train/F0460/MID1/P04853_face5.jpg',
#   'data/train/F0460/MID1/P04859_face3.jpg',
#   'data/train/F0460/MID1/P04854_face2.jpg',
#   'data/train/F0460/MID1/P04875_face3.jpg',
#   'data/train/F0460/MID1/P04857_face3.jpg',
#   'data/train/F0460/MID1/P04871_face2.jpg'],
#  'F0460/MID9': ['data/train/F0460/MID9/P04874_face2.jpg',
#   'data/train/F0460/MID9/P04873_face2.jpg'],
#  'F0460/MID7': ['data/train/F0460/MID7/P04867_face2.jpg',
#   'data/train/F0460/MID7/P04861_face1.jpg',
#   'data/train/F0460/MID7/P04868_face2.jpg',
#   'data/train/F0460/MID7/P04865_face2.jpg',
#   'data/train/F0460/MID7/P04863_face2.jpg'],
#  'F0460/MID10': ['data/train/F0460/MID10/P04880_face1.jpg',
#   'data/train/F0460/MID10/P04877_face2.jpg'],
#  'F0460/MID2': ['data/train/F0460/MID2/P04854_face4.jpg'],
#  'F0460/MID5': ['data/train/F0460/MID5/P04855_face3.jpg',
#   'data/train/F0460/MID5/P04853_face4.jpg',
#   'data/train/F0460/MID5/P04867_face1.jpg',
#   'data/train/F0460/MID5/P04875_face1.jpg',
#   'data/train/F0460/MID5/P04854_face1.jpg',
#   'data/train/F0460/MID5/P04864_face1.jpg',
#   'data/train/F0460/MID5/P04869_face1.jpg',
#   'data/train/F0460/MID5/P04851_face2.jpg',
#   'data/train/F0460/MID5/P04862_face1.jpg',
#   'data/train/F0460/MID5/P04865_face1.jpg',
#   'data/train/F0460/MID5/P04868_face1.jpg',
#   'data/train/F0460/MID5/P04871_face3.jpg',
#   'data/train/F0460/MID5/P04863_face1.jpg'],
#  'F0460/MID4': ['data/train/F0460/MID4/P04872_face2.jpg',
#   'data/train/F0460/MID4/P04855_face4.jpg',
#   'data/train/F0460/MID4/P04879_face2.jpg',
#   'data/train/F0460/MID4/P04874_face1.jpg',
#   'data/train/F0460/MID4/P04860_face2.jpg',
#   'data/train/F0460/MID4/P04858_face1.jpg',
#   'data/train/F0460/MID4/P04873_face1.jpg',
#   'data/train/F0460/MID4/P04875_face2.jpg',
#   'data/train/F0460/MID4/P04854_face3.jpg',
#   'data/train/F0460/MID4/P04859_face1.jpg',
#   'data/train/F0460/MID4/P04851_face3.jpg',
#   'data/train/F0460/MID4/P04857_face1.jpg',
#   'data/train/F0460/MID4/P04871_face1.jpg',
#   'data/train/F0460/MID4/P04880_face2.jpg',
#   'data/train/F0460/MID4/P04877_face1.jpg'],
#  'F0460/MID3': ['data/train/F0460/MID3/P04858_face2.jpg',
#   'data/train/F0460/MID3/P04855_face2.jpg',
#   'data/train/F0460/MID3/P04854_face5.jpg',
#   'data/train/F0460/MID3/P04859_face2.jpg',
#   'data/train/F0460/MID3/P04851_face1.jpg',
#   'data/train/F0460/MID3/P04857_face2.jpg'],
#  'F0494/MID1': ['data/train/F0494/MID1/P05223_face3.jpg',
#   'data/train/F0494/MID1/P05222_face1.jpg',
#   'data/train/F0494/MID1/P05221_face4.jpg',
#   'data/train/F0494/MID1/P05219_face5.jpg',
#   'data/train/F0494/MID1/P05227_face4.jpg',
#   'data/train/F0494/MID1/P05226_face5.jpg'],
#  'F0494/MID2': ['data/train/F0494/MID2/P05223_face2.jpg',
#   'data/train/F0494/MID2/P05222_face5.jpg',
#   'data/train/F0494/MID2/P05227_face2.jpg',
#   'data/train/F0494/MID2/P05221_face2.jpg',
#   'data/train/F0494/MID2/P05219_face3.jpg',
#   'data/train/F0494/MID2/P05226_face2.jpg'],
#  'F0494/MID5': ['data/train/F0494/MID5/P05227_face3.jpg',
#   'data/train/F0494/MID5/P05219_face1.jpg',
#   'data/train/F0494/MID5/P05221_face1.jpg',
#   'data/train/F0494/MID5/P05226_face1.jpg'],
#  'F0494/MID4': ['data/train/F0494/MID4/P05222_face3.jpg',
#   'data/train/F0494/MID4/P05227_face1.jpg',
#   'data/train/F0494/MID4/P05221_face3.jpg',
#   'data/train/F0494/MID4/P05219_face2.jpg',
#   'data/train/F0494/MID4/P05226_face3.jpg',
#   'data/train/F0494/MID4/P05220_face1.jpg'],
#  'F0494/MID3': ['data/train/F0494/MID3/P05222_face4.jpg',
#   'data/train/F0863/MID2/P09120_face2.jpg'],
#  'F0897/MID1': ['data/train/F0897/MID1/P09467_face2.jpg',
#   'data/train/F0897/MID1/P09466_face1.jpg',
#   'data/train/F0897/MID1/P09465_face1.jpg',
#   'data/train/F0897/MID1/P09468_face2.jpg',
#   'data/train/F0897/MID1/P09463_face1.jpg',
#   'data/train/F0897/MID1/P09469_face2.jpg',
#   'data/train/F0897/MID1/P09464_face4.jpg',
#   'data/train/F0897/MID1/P09462_face1.jpg'],
#  'F0897/MID5': ['data/train/F0897/MID5/P09469_face1.jpg'],
#  'F0897/MID4': ['data/train/F0897/MID4/P09464_face3.jpg'],
#  'F0299/MID1': ['data/train/F0299/MID1/P03183_face2.jpg',
#   'data/train/F0299/MID1/P03188_face3.jpg',
#   'data/train/F0299/MID1/P03185_face1.jpg',
#   'data/train/F0299/MID1/P03191_face1.jpg',
#   'data/train/F0299/MID1/P03179_face2.jpg',
#   'data/train/F0299/MID1/P03196_face1.jpg',
#   'data/train/F0299/MID1/P03182_face1.jpg',
#   'data/train/F0299/MID1/P03178_face1.jpg',
#   'data/train/F0299/MID1/P03190_face1.jpg',
#   'data/train/F0299/MID1/P03184_face1.jpg',
#   'data/train/F0299/MID1/P03189_face2.jpg',
#   'data/train/F0299/MID1/P03181_face1.jpg',
#   'data/train/F0299/MID1/P03195_face1.jpg',
#   'data/train/F0299/MID1/P03187_face3.jpg',
#   'data/train/F0299/MID1/P03194_face1.jpg',
#   'data/train/F0299/MID1/P03180_face2.jpg',
#   'data/train/F0299/MID1/P03192_face2.jpg',
#   'data/train/F0299/MID1/P03186_face3.jpg'],
#  'F0299/MID2': ['data/train/F0299/MID2/P03197_face2.jpg',
#   'data/train/F0299/MID2/P03179_face1.jpg',
#   'data/train/F0299/MID2/P03188_face2.jpg',
#   'data/train/F0299/MID2/P03185_face2.jpg',
#   'data/train/F0299/MID2/P03191_face2.jpg',
#   'data/train/F0299/MID2/P03196_face2.jpg',
#   'data/train/F0299/MID2/P03182_face2.jpg',
#   'data/train/F0299/MID2/P03189_face3.jpg',
#   'data/train/F0299/MID2/P03178_face2.jpg',
#   'data/train/F0299/MID2/P03190_face3.jpg',
#   'data/train/F0299/MID2/P03181_face2.jpg',
#   'data/train/F0299/MID2/P03195_face2.jpg',
#   'data/train/F0299/MID2/P03187_face1.jpg',
#   'data/train/F0299/MID2/P03180_face1.jpg',
#   'data/train/F0299/MID2/P03194_face2.jpg',
#   'data/train/F0299/MID2/P03192_face1.jpg',
#   'data/train/F0299/MID2/P03186_face2.jpg'],
#  'F0299/MID5': ['data/train/F0299/MID5/P03191_face3.jpg',
#   'data/train/F0299/MID5/P03196_face3.jpg',
#   'data/train/F0299/MID5/P03190_face2.jpg',
#   'data/train/F0299/MID5/P03195_face3.jpg',
#   'data/train/F0299/MID5/P03192_face3.jpg'],
#  'F0299/MID3': ['data/train/F0299/MID3/P03189_face1.jpg',
#   'data/train/F0299/MID3/P03187_face2.jpg',
#   'data/train/F0299/MID3/P03186_face1.jpg'],
#  'F0093/MID1': ['data/train/F0093/MID1/P00959_face1.jpg',
#   'data/train/F0093/MID1/P00952_face1.jpg',
#   'data/train/F0093/MID1/P00960_face2.jpg',
#   'data/train/F0093/MID1/P00955_face1.jpg',
#   'data/train/F0093/MID1/P00958_face2.jpg',
#   'data/train/F0093/MID1/P00953_face2.jpg',
#   'data/train/F0093/MID1/P00956_face1.jpg',
#   'data/train/F0093/MID1/P00957_face1.jpg',
#   'data/train/F0093/MID1/P00951_face2.jpg'],
#  'F0093/MID4': ['data/train/F0093/MID4/P00957_face3.jpg'],
#  'F0093/MID3': ['data/train/F0093/MID3/P00955_face2.jpg',
#   'data/train/F0093/MID3/P00958_face1.jpg',
#   'data/train/F0093/MID3/P00960_face3.jpg',
#   'data/train/F0093/MID3/P00953_face1.jpg',
#   'data/train/F0093/MID3/P00956_face2.jpg'],
#  'F0631/MID1': ['data/train/F0631/MID1/P06625_face2.jpg',
#   'data/train/F0631/MID1/P06623_face2.jpg',
#   'data/train/F0631/MID1/P06627_face1.jpg'],
#  ...}

# %%
#get the raltionships dataframe
df = pd.read_csv("csv_files/train_relationships.csv")

#get isolate the the family/member portions to compare
all_family_members = []
for img in all_images:
    split_path = img.split('/')
    all_family_members.append(split_path[2]+'/'+split_path[3])

#some relationships are not present within the relationship csv
#remove them by only keeping the ones mentioned in the dataset
df = df[df['p1'].isin(all_family_members)]
df = df[df['p2'].isin(all_family_members)]

# %%
#seperate the training and validation labels
train = df[~df['p1'].str.contains(validation_set)]
val = df[df['p1'].str.contains(validation_set)]

#turn dataframes to tuples to get labels
train = list(zip(train['p1'].values, train['p2'].values))
val = list(zip(val['p1'].values, val['p2'].values))

print(len(train))
print(len(val))
# Out:
# 3066
# 296

# %%
print(len(train))
train[:10] #labels
# Out:
# 3066
# [('F0002/MID1', 'F0002/MID3'),
#  ('F0002/MID2', 'F0002/MID3'),
#  ('F0005/MID1', 'F0005/MID2'),
#  ('F0005/MID3', 'F0005/MID2'),
#  ('F0009/MID1', 'F0009/MID4'),
#  ('F0009/MID1', 'F0009/MID3'),
#  ('F0009/MID1', 'F0009/MID2'),
#  ('F0009/MID1', 'F0009/MID6'),
#  ('F0009/MID2', 'F0009/MID4'),
#  ('F0009/MID2', 'F0009/MID6')]

# %%
#create a generator
def gen(family_member_labels, family_member_map, batch_size=16):
    while True:
        #sample from half of true labels - don't repeat grab
        half_batch_size = int(batch_size/2)
        batch_family_members = sample(family_member_labels, half_batch_size)
        #all these should be of label 1
        label = np.ones(len(batch_family_members))

        #grab data that isn't a combination from the labels set
        # create a set of size of 'batch size'
        fam_mem_keys = list(family_member_map.keys())
        while len(batch_family_members) < batch_size:
            #get random numbers to choose
            rand_num = np.random.randint(0, len(fam_mem_keys), 2)
            #get random family member
            fam_mem_1 = fam_mem_keys[rand_num[0]]
            fam_mem_2 = fam_mem_keys[rand_num[1]]

            #check if the two random people are family members - do not want that
            condition_1 = (fam_mem_1, fam_mem_2)
            condition_2 = (fam_mem_2, fam_mem_1)
            if fam_mem_1 not in fam_mem_2 and condition_1 not in family_member_labels and condition_2 not in family_member_labels:
                #add onto combination as not being family
                batch_family_members.append(condition_1)
                #add label as 0 for not family
                label = np.concatenate([label,[0]])

    #     print(batch_family_members)
    #     print(label)
    #     print('------------------')

        person_1_imgs = []
        person_2_imgs = []
        #get photos for each person
        for fam_mem_tup in batch_family_members:
            #peson 1's set of images
            mem_1_all_imgs = family_member_map[fam_mem_tup[0]]
            #person 2's set of images
            mem_2_all_imgs = family_member_map[fam_mem_tup[1]]

            #select random image
            person_1_choice = choice(mem_1_all_imgs)
            person_2_choice = choice(mem_2_all_imgs)
            #turn the images into arrays
            for person, pic_path in enumerate([person_1_choice, person_2_choice]):
                #read the image
                img = cv2.imread(pic_path)
                #turn to array
                img = np.array(img).astype(np.float)
                img_arr = preprocess_input(img)

                #add to lst
                if person == 0: #person 1
                    person_1_imgs.append(img_arr)
                else: #person 2
                    person_2_imgs.append(img_arr)

        #turn to numpy arrays
        person_1_imgs = np.asarray(person_1_imgs)
        person_2_imgs = np.asarray(person_2_imgs)

    #     print(label)
    #     print('------------------')
    #     print(len(person_1_imgs))
    #     print(type(person_1_imgs))
    #     print('------------------')
    #     print(len(person_2_imgs))
    #     print(type(person_2_imgs))


        yield [person_1_imgs, person_2_imgs], label

# %%
gen(train, train_person_to_images_map, batch_size=16)
# Out:
# <generator object gen at 0x13db49480>

# %%
from tensorflow.keras import models

# %%
from keras.models import model_from_json
model = model_from_json(open("facenet_model.json", "r").read())
model.load_weights('facenet_weights.h5')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-214-4ab2439eb3aa> in <module>
#       1 from keras.models import model_from_json
# ----> 2 model = model_from_json(open("facenet_model.json", "r").read())
#       3 model.load_weights('facenet_weights.h5')
#       4 model.summary()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'facenet_model.json'

# %%
# img = read_img('../data/train/F0009/MID1/P10569_face2.jpg')
facenet_model = models.load_model("facenet/facenet_keras.h5")
facenet_model.load_weights("facenet/facenet_keras_weights.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-213-4d6c7a480ed7> in <module>
#       1 # img = read_img('../data/train/F0009/MID1/P10569_face2.jpg')
# ----> 2 facenet_model = models.load_model("facenet/facenet_keras.h5")
#       3 facenet_model.load_weights("facenet/facenet_keras_weights.h5")
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model(filepath, custom_objects, compile)
#     201   opened_new_file = not isinstance(filepath, h5py.File)
#     202   if opened_new_file:
# --> 203     f = h5py.File(filepath, mode='r')
#     204   else:
#     205     f = filepath
#
# /anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# /anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
from tensorflow.keras.applications.vgg19 import VGG19

def baseline_model():
    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

#     base_model = VGGFace(model='resnet50', include_top=False)
    
    base_model = VGG19(weights='imagenet', include_top=False)
    
    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    # x1_ = Reshape(target_shape=(7*7, 2048))(x1)
    # x2_ = Reshape(target_shape=(7*7, 2048))(x2)
    #
    # x_dot = Dot(axes=[2, 2], normalize=True)([x1_, x2_])
    # x_dot = Flatten()(x_dot)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x = Multiply()([x1, x2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(100, activation="relu")(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

#     model.summary()

    return model

# %%
model = baseline_model()
# model.load_weights(file_path)
model.fit_generator(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=20, verbose=2,
                    workers=4, steps_per_epoch=200, validation_steps=100)
# Out:
# W0529 17:16:21.793153 4540057024 training_generator.py:409] Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/20
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-11:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Epoch 1/20
#   File "/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-220-740c2dee887c> in <module>
#       3 model.fit_generator(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
#       4                     validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=20, verbose=2,
# ----> 5                     workers=4, steps_per_epoch=200, validation_steps=100)
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1513         shuffle=shuffle,
#    1514         initial_epoch=initial_epoch,
# -> 1515         steps_name='steps_per_epoch')
#    1516
#    1517   def evaluate_generator(self,
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     255
#     256       is_deferred = not model._is_compiled
# --> 257       batch_outs = batch_function(*batch_data)
#     258       if not isinstance(batch_outs, list):
#     259         batch_outs = [batch_outs]
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1257       else:
#    1258         self._make_fit_function()
# -> 1259         outputs = self._fit_function(ins)  # pylint: disable=not-callable
#    1260
#    1261     if reset_metrics:
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3215         value = math_ops.cast(value, tensor.dtype)
#    3216       converted_inputs.append(value)
# -> 3217     outputs = self._graph_fn(*converted_inputs)
#    3218     return nest.pack_sequence_as(self._outputs_structure,
#    3219                                  [x.numpy() for x in outputs])
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#     556       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     557           list(kwargs.keys()), list(self._arg_keywords)))
# --> 558     return self._call_flat(args)
#     559
#     560   def _filtered_call(self, args, kwargs):
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args)
#     625     # Only need to override the gradient in graph mode and when we have outputs.
#     626     if context.executing_eagerly() or not self.outputs:
# --> 627       outputs = self._inference_function.call(ctx, args)
#     628     else:
#     629       self._register_gradient()
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args)
#     413             attrs=("executor_type", executor_type,
#     414                    "config_proto", config),
# --> 415             ctx=ctx)
#     416       # Replace empty list with None
#     417       outputs = outputs or None
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      59                                                op_name, inputs, attrs,
# ---> 60                                                num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# def read_img(path):
#     img = cv2.imread(path)
#     img = np.array(img).astype(np.float)
#     return preprocess_input(img)


# def gen(list_tuples, person_to_images_map, batch_size=16):
#     ppl = list(person_to_images_map.keys())
#     while True:
#         batch_tuples = sample(list_tuples, batch_size // 2)
#         labels = [1] * len(batch_tuples)
# #         print(batch_tuples)
# #         print(labels)
#         while len(batch_tuples) < batch_size:
#             p1 = choice(ppl)
#             p2 = choice(ppl)
# #             print('p1: ', p1)
# #             print('p2: ', p2)
#             if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
#                 batch_tuples.append((p1, p2))
#                 labels.append(0)
# #         print(batch_tuples)
# #         print(labels)
#         for x in batch_tuples:
# #             print('x:, ', x)
#             if not len(person_to_images_map[x[0]]):
# #                 print('x[0]:, ', x)
#                 print(x[0])
# #         print('------------------------')
#         X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
# #         print(len(X1))
# #         print(X1)
# #         print('------------------------')
#         X1 = np.array([read_img(x) for x in X1])
# #         print(X1)
# #         print('------------------------')
#         X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
#         X2 = np.array([read_img(x) for x in X2])
        
# #         print(type(X1))
# #         print(type(X2))
# #         print([X1,X2])
#         yield [X1, X2], labels


# gen(train, train_person_to_images_map, batch_size=16)
# Out:
# <generator object gen at 0x13db494f8>

# %%
# gen(train, train_person_to_images_map, batch_size=16)

# %%
# def gen(list_tuples, person_to_images_map, batch_size=16):
#     ppl = list(person_to_images_map.keys())
#     while True:
#         batch_tuples = sample(list_tuples, batch_size // 2)
#         labels = [1] * len(batch_tuples)
#         while len(batch_tuples) < batch_size:
#             p1 = choice(ppl)
#             p2 = choice(ppl)

#             if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
#                 batch_tuples.append((p1, p2))
#                 labels.append(0)

#         for x in batch_tuples:
#             if not len(person_to_images_map[x[0]]):
#                 print(x[0])

#         X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
#         X1 = np.array([read_img(x) for x in X1])

#         X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
#         X2 = np.array([read_img(x) for x in X2])
        
# #         print(X1)
        
#         yield [X1, X2], labels
        
# gen(train, train_person_to_images_map, batch_size=16)

# %%
# pip install opencv-python
